# %% [markdown]
# # DSCI 525 - Web and Cloud Computing

# %% [markdown]
# Milestone 2: Your team is planning to migrate to the cloud. AWS gave 400$ (100$ each) to your team to support this. As part of this initiative, your team needs to set up a server in the cloud, a collaborative environment for your team, and later move your data to the cloud. After that, your team can wrangle the data in preparation for machine learning.
#
# ## Milestone 2 checklist
# You will have mainly 2 tasks. Here is the checklist...
# - To set up a collaborative environment
#     - Setup your EC2 instance with JupyterHub.
#     - Install all necessary things needed in your UNIX server (amazon ec2 instance).
#     - Set up your S3 bucket.
#     - Move the data that you wrangled in your last milestone to s3.
#     - To move data from s3.
# - Wrangle the data in preparation for machine learning
#     - Get the data from S3 in your notebook and make data ready for machine learning.

# %% [markdown]
# **Keep in mind:**
#
# - _All services you use are in region us-west-2._
#
# - _Don't store anything in these servers or storage that represents your identity as a student (like your student ID number) ._
#
# - _Use only default VPC and subnet._
#
# - _No IP addresses are visible when you provide the screenshot._
#
# - _You do proper budgeting so that you don't run out of credits._
#
# - _We want one single notebook for grading, and it's up to your discretion on how you do it. ***So only one person in your group needs to spin up a big instance and a ```t2.xlarge``` is of decent size.***_
#
# - _Please stop the instance when not in use. This can save you some bucks, but it's again up to you and how you budget your money. Maybe stop it if you or your team won't use it for the next 5 hours?
#
# - _Your AWS lab will shut down after 3 hours 30 min. When you start it again, your AWS credentials (***access key***,***secret***, and ***session token***) will change, and you want to update your credentials file with the new one. _
#
# - _Say something went wrong and you want to spin up another EC2 instance, then make sure you terminate the previous one._
#
# - _We will be choosing the storage to be ```Delete on Termination```, which means that stored data in your instance will be lost upon termination. Make sure you save any data to S3 and download the notebooks to your laptop so that next time you have your jupyterHub in a different instance, you can upload your notebook there._
#
# _***Outside of Milestone:*** If you are working as an individual just to practice setting up EC2 instances, make sure you select ```t2.large``` instance (not anything bigger than that as it can cost you money). I strongly recommend you spin up your own instance and experiment with the s3 bucket in doing something (there are many things that we learned and practical work from additional instructions and video series) to get comfortable with AWS. But we won't be looking at it for a grading purpose._
#
# ***NOTE:*** Everything you want for this notebook is discussed in lecture 3, lecture 4, and setup instructions.

# %% [markdown]
# ### 1. Setup your EC2 instance

# %% [markdown]
# rubric={correctness:20}

# %% [markdown]
# #### Please attach this screen shots from your group for grading.
# https://github.ubc.ca/mds-2021-22/DSCI_525_web-cloud-comp_students/blob/master/release/milestone2/image/1_result.png

# %%
from PIL import Image

# %%
Image.open("img/525_m2_1.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1320x447 at 0x7F72E4791910>

# %% [markdown]
# ### 2. Setup your JupyterHub

# %% [markdown]
# rubric={correctness:20}

# %% [markdown]
# #### Please attach this screen shots from your group for grading
# I want to see all the group members here in this screenshot https://github.ubc.ca/mds-2021-22/DSCI_525_web-cloud-comp_students/blob/master/release/milestone2/image/2_result.png

# %%
Image.open("img/525_m2_2.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=895x353 at 0x7F72E64DF250>

# %% [markdown]
# ### 3. Setup the server

# %% [markdown]
# rubric={correctness:20}

# %% [markdown]
# 3.1) Add your team members to EC2 instance.
#
# 3.2) Setup a common data folder to download data, and this folder should be accessible by all users in the JupyterHub.
#
# 3.3)(***OPTIONAL***) Setup a sharing notebook environment.
#
# 3.4) Install and configure AWS CLI.

# %% [markdown]
# #### Please attach this screen shots from your group for grading
#
# Make sure you mask the IP address refer [here](https://www.anysoftwaretools.com/blur-part-picture-mac/).
#
# https://github.ubc.ca/mds-2021-22/DSCI_525_web-cloud-comp_students/blob/master/release/milestone2/image/3_result.png

# %%
Image.open("img/525_m2_3.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=816x67 at 0x7F72E669B340>

# %% [markdown]
# ### 4. Get the data what we wrangled in our first milestone.

# %% [markdown]
# You have to install the packages that are needed. Refer this TLJH [document]( https://tljh.jupyter.org/en/latest/howto/env/user-environment.html).Refer ```pip``` section.
#
# Don't forget to add option -E. This way, all packages that you install will be available to other users in your JupyterHub.
# These packages you must install and install other packages needed for your wrangling.
#
#     sudo -E pip install pandas
#     sudo -E pip install pyarrow
#     sudo -E pip install s3fs

# %% [markdown]
# As in the last milestone, we looked at getting the data transferred from Python to R, and we have different solutions. Henceforth, I uploaded the parquet file format, which we can use moving forward.

# %%
import re
import os
import glob
import zipfile
import requests
from urllib.request import urlretrieve
import json
import pandas as pd

# %% [markdown]
# Rememeber here we gave the folder that we created in Step 3.2 as we made it available for all the users in a group.

# %%
# Necessary metadata
article_id = 14226968  # this is the unique identifier of the article on figshare
url = f"https://api.figshare.com/v2/articles/{article_id}"
headers = {"Content-Type": "application/json"}
output_directory = os.path.abspath(os.path.join(os.getcwd(), os.pardir)) + "/data/shared/"
print(output_directory)
# Out:
# /home/jupyter-james/Web-Cloud-Group17/data/shared/

# %%
response = requests.request("GET", url, headers=headers)
data = json.loads(response.text)  # this contains all the articles data, feel free to check it out
files = data["files"]             # this is just the data about the files, which is what we want
files
# Out:
# [{'id': 26844650,
#   'name': 'allyears.csv.zip',
#   'size': 2405908113,
#   'is_link_only': False,
#   'download_url': 'https://ndownloader.figshare.com/files/26844650',
#   'supplied_md5': '9e046ac05ecd2c32a256a47dd1098b81',
#   'computed_md5': '9e046ac05ecd2c32a256a47dd1098b81'},
#  {'id': 26863682,
#   'name': 'individual_years.zip',
#   'size': 1896206676,
#   'is_link_only': False,
#   'download_url': 'https://ndownloader.figshare.com/files/26863682',
#   'supplied_md5': '921da748974b07b2a70bbfcc04535a77',
#   'computed_md5': '921da748974b07b2a70bbfcc04535a77'},
#  {'id': 27515426,
#   'name': 'combined_model_data.csv.zip',
#   'size': 821308997,
#   'is_link_only': False,
#   'download_url': 'https://ndownloader.figshare.com/files/27515426',
#   'supplied_md5': '7638434c44a7d29cbb29fe200b4fd65d',
#   'computed_md5': '7638434c44a7d29cbb29fe200b4fd65d'},
#  {'id': 27520682,
#   'name': 'combined_model_data_parti.parquet.zip',
#   'size': 519743915,
#   'is_link_only': False,
#   'download_url': 'https://ndownloader.figshare.com/files/27520682',
#   'supplied_md5': '02f4e3df8d16580a02291de225072689',
#   'computed_md5': '02f4e3df8d16580a02291de225072689'},
#  {'id': 27520808,
#   'name': 'combined_model_data.parquet',
#   'size': 565872005,
#   'is_link_only': False,
#   'download_url': 'https://ndownloader.figshare.com/files/27520808',
#   'supplied_md5': 'ae63699ab21ffa8006559c6afbcd2271',
#   'computed_md5': 'ae63699ab21ffa8006559c6afbcd2271'}]

# %%
files_to_dl = ["combined_model_data_parti.parquet.zip"]  ## Please download the partitioned 
for file in files:
    if file["name"] in files_to_dl:
        os.makedirs(output_directory, exist_ok=True)
        urlretrieve(file["download_url"], output_directory + file["name"])

# %%
with zipfile.ZipFile(os.path.join(output_directory, "combined_model_data_parti.parquet.zip"), 'r') as f:
    f.extractall(output_directory)

# %% [markdown]
# ### 5. Setup your S3 bucket and move data

# %% [markdown]
# rubric={correctness:20}

# %% [markdown]
# 5.1)  Create a bucket name should be mds-s3-xxx. Replace xxx with your "groupnumber".
#
# 5.2)  Create your first folder called "output".
#
# 5.3) Move the "observed_daily_rainfall_SYD.csv" file from the Milestone1 data folder to your s3 bucket from your local computer.
#
# 5.4) Moving the parquet file we downloaded(combined_model_data_parti.parquet) in step 4 to S3 using the cli what we installed in step 3.4.

# %%
# !aws configure set aws_access_key_id "ASIAQ3IZ36HLY57PWNMW"
# !aws configure set aws_secret_access_key "Nb0yGCyeulDzAB1m63fMmTzMlC2mACanVAocKh8Z"
# !aws configure set aws_session_token ""
# !aws s3 cp ../data/shared/ "s3://mds-s3-17" --recursive
# Out:
# upload: ../data/shared/__MACOSX/combined_model_data_parti.parquet/._.DS_Store to s3://mds-s3-17/__MACOSX/combined_model_data_parti.parquet/._.DS_Store
# upload: ../data/shared/combined_model_data_parti.parquet/.DS_Store to s3://mds-s3-17/combined_model_data_parti.parquet/.DS_Store
# upload: ../data/shared/combined_model_data_parti.parquet/model=ACCESS-CM2/04408a4423dc42748be9943c6b309281.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=ACCESS-CM2/04408a4423dc42748be9943c6b309281.parquet
# upload: ../data/shared/combined_model_data_parti.parquet.zip to s3://mds-s3-17/combined_model_data_parti.parquet.zip
# upload: ../data/shared/combined_model_data_parti.parquet/model=AWI-ESM-1-1-LR/e9f7e8fe66f2429eb1e51aae884e96c1.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=AWI-ESM-1-1-LR/e9f7e8fe66f2429eb1e51aae884e96c1.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=ACCESS-ESM1-5/78a7a0f251ad4d7d8c1f84648256ede0.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=ACCESS-ESM1-5/78a7a0f251ad4d7d8c1f84648256ede0.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=BCC-ESM1/b47dee1370e640c192266776e5af44b2.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=BCC-ESM1/b47dee1370e640c192266776e5af44b2.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=BCC-CSM2-MR/8ad0c36dc0dc41319dfba17bd1bc7f22.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=BCC-CSM2-MR/8ad0c36dc0dc41319dfba17bd1bc7f22.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=CMCC-CM2-HR4/bd6cc563dd314a97bc8e98274d16be49.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=CMCC-CM2-HR4/bd6cc563dd314a97bc8e98274d16be49.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=CMCC-CM2-SR5/56163669eb7344688ff5ab7a3c10cf9b.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=CMCC-CM2-SR5/56163669eb7344688ff5ab7a3c10cf9b.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=CanESM5/db274e263c384399a57836f56ad6114e.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=CanESM5/db274e263c384399a57836f56ad6114e.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=CMCC-ESM2/5242abbeac54498f8f139bfd1dbb99b4.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=CMCC-ESM2/5242abbeac54498f8f139bfd1dbb99b4.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=EC-Earth3-Veg-LR/a886f110edfc4eecab4445233410666f.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=EC-Earth3-Veg-LR/a886f110edfc4eecab4445233410666f.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=FGOALS-f3-L/65263166db0e41268d4cb4d90b42712e.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=FGOALS-f3-L/65263166db0e41268d4cb4d90b42712e.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=FGOALS-g3/6578ee74bb02405dbf5e6f94c9709cb4.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=FGOALS-g3/6578ee74bb02405dbf5e6f94c9709cb4.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=GFDL-ESM4/ca50b1a8a817412fb1e4c3bed0f3e24c.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=GFDL-ESM4/ca50b1a8a817412fb1e4c3bed0f3e24c.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=GFDL-CM4/107b2ce5cbc7472aa2e2e28ddf0deea7.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=GFDL-CM4/107b2ce5cbc7472aa2e2e28ddf0deea7.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=INM-CM4-8/8859848c50ce432a80c42d794e650ae7.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=INM-CM4-8/8859848c50ce432a80c42d794e650ae7.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=INM-CM5-0/049d6062291f464fb92b02150af78090.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=INM-CM5-0/049d6062291f464fb92b02150af78090.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=KIOST-ESM/9ff38f66421c4441aa62c4bea7cfaa11.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=KIOST-ESM/9ff38f66421c4441aa62c4bea7cfaa11.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=MIROC6/ddcceb0041404def9b800ec1c2169fef.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=MIROC6/ddcceb0041404def9b800ec1c2169fef.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=MPI-ESM-1-2-HAM/1f03605129654f2a98f3d4b37575a77b.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=MPI-ESM-1-2-HAM/1f03605129654f2a98f3d4b37575a77b.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=MPI-ESM1-2-LR/41bea46f26274b0282db7b0a6b49b852.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=MPI-ESM1-2-LR/41bea46f26274b0282db7b0a6b49b852.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=MPI-ESM1-2-HR/b227cd7e7d694175a7fbf2e360b130a7.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=MPI-ESM1-2-HR/b227cd7e7d694175a7fbf2e360b130a7.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=MRI-ESM2-0/5a89546814ce4f8ba9c909d9b23fcc4d.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=MRI-ESM2-0/5a89546814ce4f8ba9c909d9b23fcc4d.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=NorESM2-LM/6df6fea798c14105833d957565e0a1f7.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=NorESM2-LM/6df6fea798c14105833d957565e0a1f7.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=NESM3/5501ec516d4648ca81e1ab6f91fe120e.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=NESM3/5501ec516d4648ca81e1ab6f91fe120e.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=NorESM2-MM/c92374efc96c4e16aa715ca5c3d7ec38.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=NorESM2-MM/c92374efc96c4e16aa715ca5c3d7ec38.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=observed/1fb1ab0dfbe246ce8786bb694c7d0563.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=observed/1fb1ab0dfbe246ce8786bb694c7d0563.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=SAM0-UNICON/9f191cf02f9a4c589c1b24020c9a8f39.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=SAM0-UNICON/9f191cf02f9a4c589c1b24020c9a8f39.parquet
# upload: ../data/shared/combined_model_data_parti.parquet/model=TaiESM1/70d5539b770b4c0b8e2ba5c16a828848.parquet to s3://mds-s3-17/combined_model_data_parti.parquet/model=TaiESM1/70d5539b770b4c0b8e2ba5c16a828848.parquet

# %%
# !aws s3 cp ../data/raw/observed_daily_rainfall_SYD.csv "s3://mds-s3-17" --recursive
# Out:
# The user-provided path ../data/raw/observed_daily_rainfall_SYD.csv does not exist.

# %% [markdown]
# #### Please attach this screen shots from your group for grading
#
# Make sure it has 3 objects.
#
# https://github.ubc.ca/mds-2021-22/DSCI_525_web-cloud-comp_students/blob/master/release/milestone2/image/4_result.png

# %%
Image.open("img/525_m2_4.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1272x719>

# %% [markdown]
# ### 6. Wrangle the data in preparation for machine learning

# %% [markdown]
# rubric={correctness:20}

# %% [markdown]
# Our data currently covers all of NSW, but say that our client wants us to create a machine learning model to predict rainfall over Sydney only. There's a bit of wrangling that needs to be done for that:
# 1. We need to query our data for only the rows that contain information covering Sydney
# 2. We need to wrangle our data into a format suitable for training a machine learning model. That will require pivoting, resampling, grouping, etc.
#
# To train an ML algorithm we need it to look like this:
#
# ||model-1_rainfall|model-2_rainfall|model-3_rainfall|...|observed_rainfall|
# |---|---|---|---|---|---|
# |0|0.12|0.43|0.35|...|0.31|
# |1|1.22|0.91|1.68|...|1.34|
# |2|0.68|0.29|0.41|...|0.57|

# %% [markdown]
# 6.1) Get the data from s3 (```combined_model_data_parti.parquet``` and ```observed_daily_rainfall_SYD.csv```)
#
# 6.2) First query for Sydney data and then drop the lat and lon columns (we don't need them).
# ```
# syd_lat = -33.86
# syd_lon = 151.21
# ```
# Expected shape ```(1150049, 2)```.
#
# 6.3) Save this processed file to s3 for later use:
#
#   Save as a csv file ```ml_data_SYD.csv``` to ```s3://mds-s3-xxx/output/```
#   expected shape ```(46020,26)``` - This includes all the models as columns and also adding additional column ```Observed``` loaded from ```observed_daily_rainfall_SYD.csv``` from s3.

# %%
### Do all your coding here

# %%
import pandas as pd
import pyarrow.parquet as pq

# %%
aws_credentials ={"key": "ASIAQ3IZ36HLY57PWNMW","secret": "Nb0yGCyeulDzAB1m63fMmTzMlC2mACanVAocKh8Z", "token": ""}
df = pd.read_parquet("s3://mds-s3-17/combined_model_data_parti.parquet/", storage_options=aws_credentials)
# Examining the file:
df.head()
# Out:
#                  time  lat_min  lat_max  lon_min  lon_max  rain (mm/day)  \
# 0 1889-01-01 12:00:00   -36.25    -35.0  140.625    142.5   3.293256e-13
# 1 1889-01-02 12:00:00   -36.25    -35.0  140.625    142.5   0.000000e+00
# 2 1889-01-03 12:00:00   -36.25    -35.0  140.625    142.5   0.000000e+00
# 3 1889-01-04 12:00:00   -36.25    -35.0  140.625    142.5   0.000000e+00
# 4 1889-01-05 12:00:00   -36.25    -35.0  140.625    142.5   1.047658e-02
#
#         model
# 0  ACCESS-CM2
# 1  ACCESS-CM2
# 2  ACCESS-CM2
# 3  ACCESS-CM2
# 4  ACCESS-CM2

# %%
# Using the provided coordinates to filter Sydney / observed model:
syd_lat = -33.86
syd_lon = 151.21

df = df[((df["lat_min"] < syd_lat) & (df["lat_max"] > syd_lat))]
df = df[((df["lon_min"] < syd_lon) & (df["lon_max"] > syd_lon))]
df_sydney = df

# Drop the lat and lon columns as instructed:
df_sydney = df_sydney.drop(columns = ["lat_min", "lat_max", "lon_min", "lon_max"])
# df_sydney = df_sydney.reset_index(drop=True).set_index('time')
df_sydney.head()
# Out:
#                       time  rain (mm/day)       model
# 552240 1889-01-01 12:00:00       0.040427  ACCESS-CM2
# 552241 1889-01-02 12:00:00       0.073777  ACCESS-CM2
# 552242 1889-01-03 12:00:00       0.232656  ACCESS-CM2
# 552243 1889-01-04 12:00:00       0.911319  ACCESS-CM2
# 552244 1889-01-05 12:00:00       0.698013  ACCESS-CM2

# %%
# Check the shape of Sydney data
df_sydney_ti = df_sydney.reset_index(drop=True).set_index('time')
df_sydney_ti.shape
# Out:
# (1150049, 2)

# %%
# Load observed data:
df_observed = pd.read_csv("s3://mds-s3-17/observed_daily_rainfall_SYD.csv", storage_options=aws_credentials)
df_observed["model"] = "observed_rainfall"
df_observed.head()
# Out:
#          time  rain (mm/day)              model
# 0  1889-01-01       0.006612  observed_rainfall
# 1  1889-01-02       0.090422  observed_rainfall
# 2  1889-01-03       1.401452  observed_rainfall
# 3  1889-01-04      14.869798  observed_rainfall
# 4  1889-01-05       0.467628  observed_rainfall

# %%
# combine the two df:
df_sydney = pd.concat([df_sydney, df_observed])

# Set the index properly:
df_sydney["time"] = pd.to_datetime(df_sydney["time"]).dt.date
df_sydney.set_index("time", inplace=True)
df_sydney.head()
# Out:
#             rain (mm/day)       model
# time
# 1889-01-01       0.040427  ACCESS-CM2
# 1889-01-02       0.073777  ACCESS-CM2
# 1889-01-03       0.232656  ACCESS-CM2
# 1889-01-04       0.911319  ACCESS-CM2
# 1889-01-05       0.698013  ACCESS-CM2

# %%
# Pivot the new df 
df_final = df_sydney.reset_index().pivot(index = 'time', columns = "model", values = "rain (mm/day)")
df_final = df_final.reset_index(drop=True)
df_final.head()
# Out:
# model  ACCESS-CM2  ACCESS-ESM1-5  AWI-ESM-1-1-LR   BCC-CSM2-MR      BCC-ESM1  \
# 0        0.040427       1.814552       35.579336  4.268112e+00  1.107466e-03
# 1        0.073777       0.303965        4.596520  1.190141e+00  1.015323e-04
# 2        0.232656       0.019976        5.927467  1.003845e-09  1.760345e-05
# 3        0.911319      13.623777        8.029624  8.225225e-02  1.808932e-01
# 4        0.698013       0.021048        2.132686  2.496841e+00  4.708019e-09
#
# model  CMCC-CM2-HR4  CMCC-CM2-SR5  CMCC-ESM2   CanESM5  EC-Earth3-Veg-LR  ...  \
# 0         11.410537  3.322009e-08   2.668800  1.321215          1.515293  ...
# 1          4.014984  1.312700e+00   0.946211  2.788724          4.771375  ...
# 2          9.660565  9.103720e+00   0.431999  0.003672          4.233980  ...
# 3          3.951528  1.317160e+01   0.368693  0.013578         15.252495  ...
# 4          2.766362  1.822940e+01   0.339267  0.002468         11.920356  ...
#
# model  MPI-ESM-1-2-HAM  MPI-ESM1-2-HR  MPI-ESM1-2-LR    MRI-ESM2-0  \
# 0         4.244226e-13   1.390174e-13   6.537884e-05  3.445495e-06
# 1         4.409552e+00   1.222283e-01   1.049131e-13  4.791993e-09
# 2         2.269300e-01   3.762301e-01   9.758706e-14  6.912302e-01
# 3         2.344586e-02   4.214019e-01   7.060915e-03  3.835721e-02
# 4         4.270161e-13   1.879692e-01   4.504985e+00  3.506923e-07
#
# model         NESM3    NorESM2-LM  NorESM2-MM  SAM0-UNICON   TaiESM1  \
# 0      1.576096e+01  4.759651e-05    2.451075     0.221324  2.257933
# 1      3.675510e-01  4.350863e-01    0.477231     3.757179  2.287381
# 2      1.562869e-01  9.561101e+00    0.023083     0.253357  1.199909
# 3      2.472226e-07  5.301038e-01    0.002699     2.185454  2.106737
# 4      1.949792e-13  1.460928e-10    0.001026     2.766507  1.763335
#
# model  observed_rainfall
# 0               0.006612
# 1               0.090422
# 2               1.401452
# 3              14.869798
# 4               0.467628
#
# [5 rows x 26 columns]

# %%
df_final.shape
# Out:
# (46020, 26)

# %%
# save the file
df_final.to_csv("s3://mds-s3-17/output/ml_data_SYD.csv", storage_options=aws_credentials, index=False)

# %% [markdown]
# How the final file format looks like
# https://github.ubc.ca/mds-2021-22/DSCI_525_web-cloud-comp_students/blob/master/release/milestone2/image/finaloutput.png
#
# Shape ```(46020,26 )```

# %% [markdown]
# (***OPTIONAL***) If you are interested in doing some benchmarking!! How much time it took to read..
# - Parquet file from your local disk ?
# - Parquet file from s3 ?
# - CSV file from s3 ?
#     For that, upload the CSV file (```combined_model_data.csv```
#      )to S3 and try to read it instead of parquet.
